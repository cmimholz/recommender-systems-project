# %% [markdown]
# # Intro
# check RS01_Recommendation_System_User_Based_Collaborative_Filtering.ipynb from day 2 for the structure.
#
# Research questions:
# - How would you develop a recommendation algorithm to win this competition?
#
# - What would you propose to solve Deezer’s general recommendation problems?
#
# - Do the two solutions above overlap, in what way and why or why not?

# %% [markdown]
# # Step 1: Import Python Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data
# Step 2: Download And Read In Data

# %%
# Set the random seed for reproducibility
random_seed = 42

# Load the full dataset
file_path = '../data/raw_data/train.csv'  # Update this with the path to your file
data = pd.read_csv(file_path)
sampled_data = data

# # Define the sample size (e.g., 1% of the dataset)
# sample_size = 0.19  # This means 1% of the data
# 
# # Generate a random sample of the dataset
# sampled_data = data.sample(frac=sample_size, random_state=random_seed)
# 
# # Save the sample to a new CSV file
# sampled_file_path = '../data/sampled_train.csv'
# #sampled_file_path = '../raw_data/train.csv'
# sampled_data.to_csv(sampled_file_path, index=False)
# 
# print(f'Sampled data saved to {sampled_file_path}')

# %% [markdown]
# ### Update requirements.txt
# pip list --format=freeze > requirements.txt

# %%
# Get the dataset information
sampled_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7558834 entries, 0 to 7558833
# Data columns (total 15 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   genre_id         int64
#  1   ts_listen        int64
#  2   media_id         int64
#  3   album_id         int64
#  4   context_type     int64
#  5   release_date     int64
#  6   platform_name    int64
#  7   platform_family  int64
#  8   media_duration   int64
#  9   listen_type      int64
#  10  user_gender      int64
#  11  user_id          int64
#  12  artist_id        int64
#  13  user_age         int64
#  14  is_listened      int64
# dtypes: int64(15)
# memory usage: 865.0 MB

# %% [markdown]
# ### Data fields
# **media_id**: identifiant of the song listened by the user
# **album_id** - identifiant of the album of the song
# **media_duration** - duration of the song
# **user_gender** -  gender of the user
# **user_id** -  anonymized id of the user
# **context_type** - type of content where the song was listened: playlist, album ...
# **release_date** - release date of the song with the format YYYYMMDD
# **ts_listen** - timestamp of the listening in UNIX time
# **platform_name** - type of os
# **platform_family** - type of device
# **user_age** - age of the user
# **listen_type** - if the songs was listened in a flow or not
# **artist_id** - identifiant of the artist of the song
# **genre_id** - identifiant of the genre of the song
# **is_listened** - 1 if the track was listened, 0 otherwise

# %%
sampled_data.describe()
# Out:
#            genre_id     ts_listen      media_id      album_id  context_type  \
# count  7.558834e+06  7.558834e+06  7.558834e+06  7.558834e+06  7.558834e+06
# mean   2.245030e+03  1.479011e+09  7.839624e+07  8.136169e+06  2.360018e+00
# std    1.308979e+04  1.189935e+07  5.133633e+07  5.460090e+06  4.659856e+00
# min    0.000000e+00  1.000000e+00  2.000580e+05  1.976000e+03  0.000000e+00
# 25%    0.000000e+00  1.478460e+09  1.376614e+07  1.255566e+06  0.000000e+00
# 50%    3.000000e+00  1.479057e+09  9.380660e+07  9.525626e+06  1.000000e+00
# 75%    2.700000e+01  1.479742e+09  1.262592e+08  1.329221e+07  2.000000e+00
# max    2.597310e+05  1.480636e+09  1.372601e+08  1.472086e+07  7.300000e+01
#
#        release_date  platform_name  platform_family  media_duration  \
# count  7.558834e+06   7.558834e+06     7.558834e+06    7.558834e+06
# mean   2.011388e+07   4.731900e-01     2.558086e-01    2.311527e+02
# std    7.570138e+04   7.353008e-01     5.481663e-01    7.999463e+01
# min    1.900010e+07   0.000000e+00     0.000000e+00    0.000000e+00
# 25%    2.009123e+07   0.000000e+00     0.000000e+00    1.960000e+02
# 50%    2.014103e+07   0.000000e+00     0.000000e+00    2.220000e+02
# 75%    2.016061e+07   1.000000e+00     0.000000e+00    2.540000e+02
# max    3.000010e+07   2.000000e+00     2.000000e+00    6.553500e+04
#
#         listen_type   user_gender       user_id     artist_id      user_age  \
# count  7.558834e+06  7.558834e+06  7.558834e+06  7.558834e+06  7.558834e+06
# mean   3.068742e-01  3.936884e-01  4.037300e+03  1.500740e+06  2.431278e+01
# std    4.611968e-01  4.885672e-01  3.954754e+03  2.519546e+06  3.767797e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00  1.800000e+01
# 25%    0.000000e+00  0.000000e+00  8.990000e+02  2.605000e+03  2.100000e+01
# 50%    0.000000e+00  0.000000e+00  2.738000e+03  1.941720e+05  2.500000e+01
# 75%    1.000000e+00  1.000000e+00  6.064000e+03  1.519461e+06  2.800000e+01
# max    1.000000e+00  1.000000e+00  1.991700e+04  1.144741e+07  3.000000e+01
#
#         is_listened
# count  7.558834e+06
# mean   6.840330e-01
# std    4.648999e-01
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    1.000000e+00
# 75%    1.000000e+00
# max    1.000000e+00

# %%
# Number of genres
print('The dataset has', sampled_data['genre_id'].nunique(), 'unique genres')

# Number of unique songs in sample
print('The dataset has', sampled_data['album_id'].nunique(), 'unique albums')

# Number of unique songs in sample
print('The dataset has', sampled_data['media_id'].nunique(), 'unique songs')

# Number of unique songs in sample
print('The dataset has', sampled_data['user_gender'].nunique(), 'unique genders')

# Number of unique songs in sample
print('The dataset has', sampled_data['artist_id'].nunique(), 'unique artists')
# Out:
# The dataset has 2922 unique genres
# The dataset has 151471 unique albums
# The dataset has 452975 unique songs
# The dataset has 2 unique genders
# The dataset has 67142 unique artists

# %%
# Plot a histogram of the media_duration (length of songs)
plt.figure(figsize=(10, 6))
plt.hist(sampled_data['media_duration'], bins=50, color='skyblue', edgecolor='black')
plt.title('Histogram of Song Lengths (Media Duration)')
plt.xlabel('Duration (seconds)')
plt.ylabel('Frequency')
plt.grid(True)

# Show the plot
plt.show()

#TODO: is this big datapoint an outlier?

# %%
release_year_grouped = sampled_data.groupby('media_duration').size().reset_index(name='count')
release_year_grouped_sorted = release_year_grouped.sort_values(by='media_duration', ascending=False)
release_year_grouped_sorted
# Out:
#       media_duration  count
# 1651           65535      2
# 1650            9158      1
# 1649            8216      3
# 1648            7575      8
# 1647            7054      6
# ...              ...    ...
# 4                  4     40
# 3                  3     41
# 2                  2      8
# 1                  1     30
# 0                  0    179
#
# [1652 rows x 2 columns]

# %% [markdown]
# As we can see there are just a few songs which have a long duration. As we think these songs are very niche and might annoy the customers, we exclude them out of the dataset. Max. length is 10 minutes.

# %%
sampled_data = sampled_data[sampled_data['media_duration'] < 600]

# %%
# Plot a histogram of the media_duration (length of songs) with a limited x-axis for better visualization
plt.figure(figsize=(10, 6))
plt.hist(sampled_data['media_duration'], bins=50, color='skyblue', edgecolor='black', range=(0, 600))
plt.title('Histogram of Song Lengths (Media Duration)')
plt.xlabel('Duration (seconds)')
plt.ylabel('Frequency')
plt.grid(True)

# Show the plot
plt.show()

# %%
# Count the occurrences of each media_id (song)
song_popularity = sampled_data['media_id'].value_counts().head(10)  # Top 10 most popular songs

# Plot the popularity of the most streamed songs
plt.figure(figsize=(10, 6))
song_popularity.plot(kind='bar', color='lightgreen', edgecolor='black')
plt.title('Top 10 Most Streamed Songs')
plt.xlabel('Media ID (Song)')
plt.ylabel('Number of Streams')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Show the plot
plt.show()

# %%
# # Plot distribution by media_id
# plt.figure(figsize=(10, 6))
# sampled_data['media_id'].value_counts().sort_index().plot(kind='bar', color='skyblue', edgecolor='black')
# plt.title('Distribution of media_id')
# plt.xlabel('Media_id')
# plt.ylabel('Count')
# plt.grid(True)
# plt.show()

# %%
# Plot distribution by album_id
plt.figure(figsize=(10, 6))
sampled_data['album_id'].value_counts().sort_index().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribution of album_id')
plt.xlabel('Album_id')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %%
# Plot distribution by user_id
plt.figure(figsize=(10, 6))
sampled_data['user_id'].value_counts().sort_index().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribution of user_id')
plt.xlabel('User_id')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %%
# Plot distribution by platform_name
plt.figure(figsize=(10, 6))
sampled_data['platform_name'].value_counts().sort_index().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribution of platform_name')
plt.xlabel('platform_name')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %%
# Plot distribution by platform_family
plt.figure(figsize=(10, 6))
sampled_data['platform_family'].value_counts().sort_index().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribution of platform_family')
plt.xlabel('platform_family')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %%
# Plot distribution by user_age
plt.figure(figsize=(10, 6))
sampled_data['user_age'].value_counts().sort_index().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribution of user_age')
plt.xlabel('user_age')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %%
# Plot distribution by user_age
plt.figure(figsize=(10, 6))
sampled_data['artist_id'].value_counts().sort_index().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribution of artist_id')
plt.xlabel('artist_id')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %%
# Plot a bar chart for user_gender distribution
plt.figure(figsize=(8, 6))
sampled_data['user_gender'].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribution of User Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.grid(axis='y')

# Show the plot
plt.show()

# %%
# Convert ts_listen to datetime and extract the year
sampled_data['ts_listen_year'] = pd.to_datetime(sampled_data['ts_listen'], unit='s').dt.year

# Plot distribution by ts_listen (listening year)
plt.figure(figsize=(10, 6))
sampled_data['ts_listen_year'].value_counts().sort_index().plot(kind='line', marker='o', color='skyblue')
plt.title('Distribution of Songs by Listening Year (ts_listen)')
plt.xlabel('Year')
plt.ylabel('Number of Songs Streamed')
plt.grid(True)
plt.show()
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_20052\3805375104.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_data['ts_listen_year'] = pd.to_datetime(sampled_data['ts_listen'], unit='s').dt.year

# %%
# Group by ts_listen_year and count the number of occurrences, then sort in descending order
release_year_grouped = sampled_data.groupby('ts_listen_year').size().reset_index(name='count')
release_year_grouped_sorted = release_year_grouped.sort_values(by='count', ascending=False)
release_year_grouped_sorted
# Out:
#     ts_listen_year    count
# 12            2016  7555846
# 1             1980      379
# 0             1970      249
# 5             2009       96
# 11            2015       29
# 4             2008       19
# 9             2013       19
# 6             2010        7
# 7             2011        7
# 10            2014        3
# 3             2001        2
# 2             1996        1
# 8             2012        1

# %%
# As there are almost only songs playeed in 2016 the others seem not be part of the dataset. Therefore we exclude them. 

# Filter the data to only include records from the year 2016
sampled_data = sampled_data[sampled_data['ts_listen_year'] == 2016]

sampled_data['ts_listen_month'] = pd.to_datetime(data['ts_listen'], unit='s').dt.month

monthly_listens_2016 = sampled_data['ts_listen_month'].value_counts().sort_index()

# Plot the distribution of listens per month in 2016
plt.figure(figsize=(10, 6))
monthly_listens_2016.plot(kind='line', marker='o', color='skyblue')
plt.title('Distribution of Songs Streamed per Month in 2016')
plt.xlabel('Month')
plt.ylabel('Number of Songs Streamed')
plt.xticks(range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# We can observe, that most data is collected in November. Therefore it might be, that the music has a bias towards christmas music, which is generally not the case if there would be a bigger dataset.

# %%
# Convert release_date to string and extract the year
sampled_data['release_year'] = sampled_data['release_date'].astype(str).str[:4].astype(int)

# Plot distribution by release_year
plt.figure(figsize=(10, 6))
sampled_data['release_year'].value_counts().sort_index().plot(kind='line', marker='o', color='lightcoral')
plt.title('Distribution of Songs by Release Year')
plt.xlabel('Year')
plt.ylabel('Number of Songs Released')
plt.grid(True)
plt.show()

# %%
# # Convert ts_listen to datetime and extract the year
# sampled_data['release_year'] = pd.to_datetime(sampled_data['release_year'], unit='s').dt.year
# Plot distribution by ts_listen (listening year), filtering out years >= 2024
sampled_data = sampled_data[sampled_data['release_year'] < 2025]

# %%
# Plot distribution by release_year
plt.figure(figsize=(10, 6))
sampled_data['release_year'].value_counts().sort_index().plot(kind='line', marker='o', color='lightcoral')
plt.title('Distribution of Songs by Release Year')
plt.xlabel('Year')
plt.ylabel('Number of Songs Released')
plt.grid(True)
lt.show()

# %%
# Plot distribution by context_type
plt.figure(figsize=(10, 6))
sampled_data['context_type'].value_counts().sort_index().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribution of context_type')
plt.xlabel('Context type')
plt.ylabel('Number of Songs played')
plt.grid(True)
plt.show()

# %%
# Plot distribution by context_type
plt.figure(figsize=(10, 6))
sampled_data['context_type'].value_counts().sort_index().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribution of context_type')
plt.xlabel('Context type')
plt.ylabel('Number of Songs played')
plt.grid(True)
plt.show()
